# %%
from ultralytics import YOLO

model = YOLO("yolo11l.pt")

results = model('./video/vid1.mp4', classes=[0], save=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 from ultralytics import YOLO
#       3 model = YOLO("yolo11l.pt")
# ----> 5 results = model('./video/vid1.mp4', classes=[0], save=True)
#
# File c:\PROJECTS\Python Pojects\Martian\CCTV People Tracking - Antigravity\C_Yolo\lib\site-packages\ultralytics\engine\model.py:178, in Model.__call__(self, source, stream, **kwargs)
#     150 def __call__(
#     151     self,
#     152     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     153     stream: bool = False,
#     154     **kwargs: Any,
#     155 ) -> Iterator[Results | torch.Tensor] | list[Results] | list[torch.Tensor]:
#     156     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     157
# ...

# %%
results = model.track(
    source=r"C:\PROJECTS\Python Pojects\Martian\CCTV People Tracking\video\vid1.mp4",
    persist=True,
    show=True,
    save=True,
    tracker="botsort.yaml"
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/881) C:\PROJECTS\Python Pojects\Martian\CCTV People Tracking\video\vid1.mp4: 384x640 3 persons, 18.2ms
# video 1/1 (frame 2/881) C:\PROJECTS\Python Pojects\Martian\CCTV People Tracking\video\vid1.mp4: 384x640 3 persons, 46.0ms
# video 1/1 (frame 3/881) C:\PROJECTS\Python Pojects\Martian\CCTV People Tracking\video\vid1.mp4: 384x640 3 persons, 62.2ms
# ...
